# %% [markdown]
# <a href="https://colab.research.google.com/github/numinousmuses/ei-keyword-spotting-project/blob/main/ei_audio_dataset_curation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Keyword Spotting Dataset Curation
#
# [![Open In Colab <](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ShawnHymel/ei-keyword-spotting/blob/master/ei-audio-dataset-curation.ipynb)
#
# Use this tool to download the Google Speech Commands Dataset, combine it with your own keywords, mix in some background noise, and upload the curated dataset to Edge Impulse. From there, you can train a neural network to classify spoken words and upload it to a microcontroller to perform real-time keyword spotting.
#
#  1. Upload samples of your own keyword (optional)
#  2. Adjust parameters in the Settings cell (you will need an [Edge Impulse](https://www.edgeimpulse.com/) account)
#  3. Run the rest of the cells! ('shift' + 'enter' on each cell)

# %% [markdown]
# ### Upload your own keyword samples
# You are welcome to use my [custom keyword dataset](https://github.com/ShawnHymel/custom-speech-commands-dataset), but note that it's limited and that I can't promise it will work well. If you want to use it, uncomment the `###Download custom dataset` cell below. You may also add your own recorded keywords to the extracted folder (`/content/custom_keywords`) to augment what's already there.
#
# If you'd rather upload your own custom keyword dataset, follow these instructions:
#
# On the left pane, in the file browser, create a directory structure containing space for your keyword audio samples. All samples for each keyword should be in a directory with that keyword's name.
#
# The audio samples should be `.wav` format, mono, and 1 second long. Bitrate and bitdepth should not matter. Samples shorter than 1 second will be padded with 0s, and samples longer than 1 second will be truncated to 1 second. The exact name of each `.wav` file does not matter, as they will be read, mixed with background noise, and saved to a separate file with an auto-generated name. Directory name does matter (it is used to determine the name of the class during neural network training).
#
# Right-click on each keyword directory and upload all of your samples. Your directory structor should look like the following:
#
# ```
# /
# |- content
# |--- custom_keywords
# |----- keyword_1
# |------- 000.wav
# |------- 001.wav
# |------- ...
# |----- keyword_2
# |------- 000.wav
# |------- 001.wav
# |------- ...
# |----- ...
# ```

# %%
### Update Node.js to the latest stable version
# !npm cache clean -f
# !npm install -g n
# !n stable
# Out:
# npm WARN using --force I sure hope you know what you are doing.
# /tools/node/bin/n -> /tools/node/lib/node_modules/n/bin/n
# + n@9.0.0
# added 1 package from 2 contributors in 0.423s
#
#
#    ╭────────────────────────────────────────────────────────────────╮
#    │                                                                │
#    │      New major version of npm available! 6.14.8 → 8.15.0       │
#    │   Changelog: https://github.com/npm/cli/releases/tag/v8.15.0   │
#    │               Run npm install -g npm to update!                │
#    │                                                                │
#    ╰────────────────────────────────────────────────────────────────╯
#
#   installing : node-v16.16.0
#        mkdir : /usr/local/n/versions/node/16.16.0
#        fetch : https://nodejs.org/dist/v16.16.0/node-v16.16.0-linux-x64.tar.xz
# ######################################################################## 100.0%
#      copying : node/16.16.0
#    installed : v16.16.0 (with npm 8.11.0)
#
# Note: the node command changed location and the old location may be remembered in your current shell.
#          old : /tools/node/bin/node
#          new : /usr/local/bin/node
# If "node --version" shows the old version then start a new shell, or reset the location hash with:
# hash -r  (for bash, zsh, ash, dash, and ksh)
# rehash   (for csh and tcsh)

# %%
### Install required packages and tools
# !python -m pip install soundfile
# !npm install -g --unsafe-perm edge-impulse-cli
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: soundfile in /usr/local/lib/python3.7/dist-packages (0.10.3.post1)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.7/dist-packages (from soundfile) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.0->soundfile) (2.21)
# npm WARN config global `--global`, `--local` are deprecated. Use `--location=global` instead.
# npm WARN deprecated debug@4.1.1: Debug versions >=3.2.0 <3.2.7 || >=4 <4.3.1 have a low-severity ReDos regression when used in a Node.js environment. It is recommended you upgrade to 3.2.7 or 4.3.1. (https://github.com/visionmedia/debug/issues/797)
# npm WARN deprecated debug@4.1.1: Debug versions >=3.2.0 <3.2.7 || >=4 <4.3.1 have a low-severity ReDos regression when used in a Node.js environment. It is recommended you upgrade to 3.2.7 or 4.3.1. (https://github.com/visionmedia/debug/issues/797)
# npm WARN deprecated har-validator@5.1.5: this library is no longer supported
# npm WARN deprecated uuid@3.4.0: Please upgrade  to version 7 or higher.  Older versions may use Math.random() in certain circumstances, which is known to be problematic.  See https://v8.dev/blog/math-random for details.
# npm WARN deprecated request-promise@4.2.4: request-promise has been deprecated because it extends the now deprecated request package, see https://github.com/request/request/issues/3142
# npm WARN deprecated @zeit/dockerignore@0.0.5: "@zeit/dockerignore" is no longer maintained
# npm WARN deprecated debug@4.1.1: Debug versions >=3.2.0 <3.2.7 || >=4 <4.3.1 have a low-severity ReDos regression when used in a Node.js environment. It is recommended you upgrade to 3.2.7 or 4.3.1. (https://github.com/visionmedia/debug/issues/797)
# npm WARN deprecated request@2.88.0: request has been deprecated, see https://github.com/request/request/issues/3142
#
# added 372 packages, and audited 373 packages in 25s
#
# 12 packages are looking for funding
#   run `npm fund` for details
#
# 6 vulnerabilities (2 moderate, 4 high)
#
# To address all issues (including breaking changes), run:
#   npm audit fix --force
#
# Run `npm audit` for details.
# npm notice
# npm notice New minor version of npm available! 8.11.0 -> 8.15.0
# npm notice Changelog: https://github.com/npm/cli/releases/tag/v8.15.0
# npm notice Run npm install -g npm@8.15.0 to update!
# npm notice

# %%
### Settings (You probably do not need to change these)
BASE_DIR = "/content"
OUT_DIR = "keywords_curated"
GOOGLE_DATASET_FILENAME = "speech_commands_v0.02.tar.gz"
GOOGLE_DATASET_URL = "http://download.tensorflow.org/data/" + GOOGLE_DATASET_FILENAME
GOOGLE_DATASET_DIR = "google_speech_commands"
CUSTOM_KEYWORDS_FILENAME = "main.zip"
CUSTOM_KEYWORDS_URL = "https://github.com/ShawnHymel/custom-speech-commands-dataset/archive/" + CUSTOM_KEYWORDS_FILENAME
CUSTOM_KEYWORDS_DIR = "custom_keywords"
CUSTOM_KEYWORDS_REPO_NAME = "custom-speech-commands-dataset-main"
CURATION_SCRIPT = "dataset-curation.py"
CURATION_SCRIPT_URL = "https://raw.githubusercontent.com/ShawnHymel/ei-keyword-spotting/master/" + CURATION_SCRIPT
UTILS_SCRIPT_URL = "https://raw.githubusercontent.com/ShawnHymel/ei-keyword-spotting/master/utils.py"
NUM_SAMPLES = 1500    # Target number of samples to mix and send to Edge Impulse
WORD_VOL = 1.0        # Relative volume of word in output sample
BG_VOL = 0.1          # Relative volume of noise in output sample
SAMPLE_TIME = 1.0     # Time (seconds) of output sample
SAMPLE_RATE = 16000   # Sample rate (Hz) of output sample
BIT_DEPTH = "PCM_16"  # Options: [PCM_16, PCM_24, PCM_32, PCM_U8, FLOAT, DOUBLE]
BG_DIR = "_background_noise_"
TEST_RATIO = 0.2      # 20% reserved for test set, rest is for training
EI_INGEST_TEST_URL = "https://ingestion.edgeimpulse.com/api/test/data"
EI_INGEST_TRAIN_URL = "https://ingestion.edgeimpulse.com/api/training/data"

# %%
### Download Google Speech Commands Dataset
# !cd {BASE_DIR}
# !wget {GOOGLE_DATASET_URL}
# !mkdir {GOOGLE_DATASET_DIR}
# !echo "Extracting..."
# !tar xfz {GOOGLE_DATASET_FILENAME} -C {GOOGLE_DATASET_DIR}
# Out:
# --2022-07-26 13:46:39--  http://download.tensorflow.org/data/speech_commands_v0.02.tar.gz
# Resolving download.tensorflow.org (download.tensorflow.org)... 108.177.13.128, 2607:f8b0:400c:c09::80
# Connecting to download.tensorflow.org (download.tensorflow.org)|108.177.13.128|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2428923189 (2.3G) [application/gzip]
# Saving to: ‘speech_commands_v0.02.tar.gz’
#
# speech_commands_v0. 100%[===================>]   2.26G   172MB/s    in 13s
#
# 2022-07-26 13:46:52 (176 MB/s) - ‘speech_commands_v0.02.tar.gz’ saved [2428923189/2428923189]
#
# Extracting...

# %%
### Pull out background noise directory
# !cd {BASE_DIR}
# !mv "{GOOGLE_DATASET_DIR}/{BG_DIR}" "{BG_DIR}"

# %%
## (Optional) Download custom dataset--uncomment the code in this cell if you want to use my custom datase

# Download, extract, and move dataset to separate directory
# !cd {BASE_DIR}
# !wget {CUSTOM_KEYWORDS_URL}
# !echo "Extracting..."
# !unzip -q {CUSTOM_KEYWORDS_FILENAME}
# !mv "{CUSTOM_KEYWORDS_REPO_NAME}/{CUSTOM_KEYWORDS_DIR}" "{CUSTOM_KEYWORDS_DIR}"
# Out:
# --2022-07-26 13:56:45--  https://github.com/ShawnHymel/custom-speech-commands-dataset/archive/main.zip
# Resolving github.com (github.com)... 140.82.113.3
# Connecting to github.com (github.com)|140.82.113.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/ShawnHymel/custom-speech-commands-dataset/zip/refs/heads/main [following]
# --2022-07-26 13:56:46--  https://codeload.github.com/ShawnHymel/custom-speech-commands-dataset/zip/refs/heads/main
# Resolving codeload.github.com (codeload.github.com)... 140.82.112.9
# Connecting to codeload.github.com (codeload.github.com)|140.82.112.9|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘main.zip’
#
# main.zip                [             <=>    ]  58.89M  8.82MB/s    in 11s
#
# 2022-07-26 13:56:57 (5.14 MB/s) - ‘main.zip’ saved [61755655]
#
# Extracting...

# %%
### User Settings (do change these)

# Location of your custom keyword samples (e.g. "/content/custom_keywords")
# Leave blank ("") for no custom keywords. set to the CUSTOM_KEYWORDS_DIR
# variable to use samples from my custom-speech-commands-dataset repo.
CUSTOM_DATASET_PATH = "/content/custom_keywords"

# Edge Impulse > your_project > Dashboard > Keys
EI_API_KEY = "ei_081b0bc5d316fdf641587eef548eb7ed0409889d2609703a4739a20e8707b3f6" 

# Comma separated words. Must match directory names (that contain samples).
# Recommended: use 2 keywords for microcontroller demo
TARGETS = "goodnight, up"

# %%
### Download curation and utils scripts
# !wget {CURATION_SCRIPT_URL}
# !wget {UTILS_SCRIPT_URL}
# Out:
# --2022-07-26 14:02:30--  https://raw.githubusercontent.com/ShawnHymel/ei-keyword-spotting/master/dataset-curation.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 17427 (17K) [text/plain]
# Saving to: ‘dataset-curation.py’
#
# dataset-curation.py 100%[===================>]  17.02K  --.-KB/s    in 0s
#
# 2022-07-26 14:02:30 (44.2 MB/s) - ‘dataset-curation.py’ saved [17427/17427]
#
# --2022-07-26 14:02:31--  https://raw.githubusercontent.com/ShawnHymel/ei-keyword-spotting/master/utils.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3966 (3.9K) [text/plain]
# Saving to: ‘utils.py’
#
# utils.py            100%[===================>]   3.87K  --.-KB/s    in 0s
#
# 2022-07-26 14:02:31 (40.8 MB/s) - ‘utils.py’ saved [3966/3966]

# %%
### Perform curation and mixing of samples with background noise
# !cd {BASE_DIR}
# !python {CURATION_SCRIPT} \
  -t "{TARGETS}" \
  -n {NUM_SAMPLES} \
  -w {WORD_VOL} \
  -g {BG_VOL} \
  -s {SAMPLE_TIME} \
  -r {SAMPLE_RATE} \
  -e {BIT_DEPTH} \
  -b "{BG_DIR}" \
  -o "{OUT_DIR}" \
  "{GOOGLE_DATASET_DIR}" \
  "{CUSTOM_DATASET_PATH}"
# Out:
# /usr/local/lib/python3.7/dist-packages/resampy/interpn.py:114: NumbaWarning: The TBB threading layer requires TBB version 2019.5 or later i.e., TBB_INTERFACE_VERSION >= 11005. Found TBB_INTERFACE_VERSION = 9107. The TBB threading layer is disabled.
#   _resample_loop_p(x, t_out, interp_win, interp_delta, num_table, scale, y)
# -----------------------------------------------------------------------
# Keyword Dataset Curation Tool
# v0.1
# -----------------------------------------------------------------------
# Gathering random background noise snippets (1500 files)
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Mixing: goodnight (1500 files)
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Mixing: up (1500 files)
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Mixing: _unknown (1500 files)
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Done!

# %%
### Use CLI tool to send curated dataset to Edge Impulse

# !cd {BASE_DIR}

# Imports
import os
import random

# Seed with system time
random.seed()

# Go through each category in our curated dataset
for dir in os.listdir(OUT_DIR):
  
  # Create list of files for one category
  paths = []
  for filename in os.listdir(os.path.join(OUT_DIR, dir)):
    paths.append(os.path.join(OUT_DIR, dir, filename))

  # Shuffle and divide into test and training sets
  random.shuffle(paths)
  num_test_samples = int(TEST_RATIO * len(paths))
  test_paths = paths[:num_test_samples]
  train_paths = paths[num_test_samples:]

  # Create arugments list (as a string) for CLI call
  test_paths = ['"' + s + '"' for s in test_paths]
  test_paths = ' '.join(test_paths)
  train_paths = ['"' + s + '"' for s in train_paths]
  train_paths = ' '.join(train_paths)
  
  # Send test files to Edge Impulse
  # !edge-impulse-uploader \
    --category testing \
    --label {dir} \
    --api-key {EI_API_KEY} \
    --silent \
    {test_paths}

  # # Send training files to Edge Impulse
  # !edge-impulse-uploader \
    --category training \
    --label {dir} \
    --api-key {EI_API_KEY} \
    --silent \
    {train_paths}
# Out:
# Streaming output truncated to the last 5000 lines.
# [ 701/1200] Uploading keywords_curated/up/up.1234.wav OK (273 ms)
# [ 702/1200] Uploading keywords_curated/up/up.0812.wav OK (375 ms)
# [ 703/1200] Uploading keywords_curated/up/up.1202.wav OK (374 ms)
# [ 704/1200] Uploading keywords_curated/up/up.0509.wav OK (329 ms)
# [ 705/1200] Uploading keywords_curated/up/up.0000.wav OK (391 ms)
# [ 706/1200] Uploading keywords_curated/up/up.0313.wav OK (498 ms)
# [ 707/1200] Uploading keywords_curated/up/up.1472.wav OK (304 ms)
# [ 708/1200] Uploading keywords_curated/up/up.1323.wav OK (324 ms)
# [ 709/1200] Uploading keywords_curated/up/up.0836.wav OK (333 ms)
# [ 710/1200] Uploading keywords_curated/up/up.1149.wav OK (329 ms)
# [ 711/1200] Uploading keywords_curated/up/up.0896.wav OK (420 ms)
# [ 712/1200] Uploading keywords_curated/up/up.0083.wav OK (365 ms)
# [ 713/1200] Uploading keywords_curated/up/up.0639.wav OK (286 ms)
# [ 714/1200] Uploading keywords_curated/up/up.1271.wav OK (409 ms)
# [ 715/1200] Uploading keywords_curated/up/up.1307.wav OK (255 ms)
# [ 716/1200] Uploading keywords_curated/up/up.0357.wav OK (459 ms)
# [ 717/1200] Uploading keywords_curated/up/up.0964.wav OK (404 ms)
# [ 718/1200] Uploading keywords_curated/up/up.0837.wav OK (329 ms)
# [ 719/1200] Uploading keywords_curated/up/up.0275.wav OK (401 ms)
# [ 720/1200] Uploading keywords_curated/up/up.1056.wav OK (350 ms)
# [ 721/1200] Uploading keywords_curated/up/up.0428.wav OK (305 ms)
# [ 722/1200] Uploading keywords_curated/up/up.1207.wav OK (403 ms)
# [ 723/1200] Uploading keywords_curated/up/up.0835.wav OK (408 ms)
# [ 724/1200] Uploading keywords_curated/up/up.0890.wav OK (415 ms)
# [ 725/1200] Uploading keywords_curated/up/up.0459.wav OK (417 ms)
# [ 726/1200] Uploading keywords_curated/up/up.0133.wav OK (404 ms)
# [ 727/1200] Uploading keywords_curated/up/up.0786.wav OK (395 ms)
# [ 728/1200] Uploading keywords_curated/up/up.1458.wav OK (314 ms)
# [ 729/1200] Uploading keywords_curated/up/up.0799.wav OK (278 ms)
# [ 730/1200] Uploading keywords_curated/up/up.0475.wav OK (324 ms)
# [ 731/1200] Uploading keywords_curated/up/up.0020.wav OK (257 ms)
# [ 732/1200] Uploading keywords_curated/up/up.1373.wav OK (295 ms)
# [ 733/1200] Uploading keywords_curated/up/up.0480.wav OK (268 ms)
# [ 734/1200] Uploading keywords_curated/up/up.0648.wav OK (362 ms)
# [ 735/1200] Uploading keywords_curated/up/up.0839.wav OK (371 ms)
# [ 736/1200] Uploading keywords_curated/up/up.1282.wav OK (400 ms)
# [ 737/1200] Uploading keywords_curated/up/up.0126.wav OK (322 ms)
# [ 738/1200] Uploading keywords_curated/up/up.1119.wav OK (283 ms)
# [ 739/1200] Uploading keywords_curated/up/up.0534.wav OK (344 ms)
# [ 740/1200] Uploading keywords_curated/up/up.0254.wav OK (282 ms)
# [ 741/1200] Uploading keywords_curated/up/up.0286.wav OK (404 ms)
# [ 742/1200] Uploading keywords_curated/up/up.0267.wav OK (315 ms)
# [ 743/1200] Uploading keywords_curated/up/up.1091.wav OK (335 ms)
# [ 744/1200] Uploading keywords_curated/up/up.0618.wav OK (364 ms)
# [ 745/1200] Uploading keywords_curated/up/up.0511.wav OK (366 ms)
# [ 746/1200] Uploading keywords_curated/up/up.1006.wav OK (328 ms)
# [ 747/1200] Uploading keywords_curated/up/up.0647.wav OK (319 ms)
# [ 748/1200] Uploading keywords_curated/up/up.0403.wav OK (404 ms)
# [ 749/1200] Uploading keywords_curated/up/up.0745.wav OK (292 ms)
# [ 750/1200] Uploading keywords_curated/up/up.0578.wav OK (368 ms)
# [ 751/1200] Uploading keywords_curated/up/up.1235.wav OK (355 ms)
# [ 752/1200] Uploading keywords_curated/up/up.1415.wav OK (305 ms)
# [ 753/1200] Uploading keywords_curated/up/up.0559.wav OK (303 ms)
# [ 754/1200] Uploading keywords_curated/up/up.1333.wav OK (373 ms)
# [ 755/1200] Uploading keywords_curated/up/up.0332.wav OK (520 ms)
# [ 756/1200] Uploading keywords_curated/up/up.0793.wav OK (283 ms)
# [ 757/1200] Uploading keywords_curated/up/up.1038.wav OK (307 ms)
# [ 758/1200] Uploading keywords_curated/up/up.0317.wav OK (268 ms)
# [ 759/1200] Uploading keywords_curated/up/up.0758.wav OK (371 ms)
# [ 760/1200] Uploading keywords_curated/up/up.0870.wav OK (305 ms)
# [ 761/1200] Uploading keywords_curated/up/up.0697.wav OK (369 ms)
# [ 762/1200] Uploading keywords_curated/up/up.0396.wav OK (310 ms)
# [ 763/1200] Uploading keywords_curated/up/up.0627.wav OK (321 ms)
# [ 764/1200] Uploading keywords_curated/up/up.0946.wav OK (332 ms)
# [ 765/1200] Uploading keywords_curated/up/up.1412.wav OK (411 ms)
# [ 766/1200] Uploading keywords_curated/up/up.0763.wav OK (399 ms)
# [ 767/1200] Uploading keywords_curated/up/up.1126.wav OK (420 ms)
# [ 768/1200] Uploading keywords_curated/up/up.0401.wav OK (392 ms)
# [ 769/1200] Uploading keywords_curated/up/up.1023.wav OK (332 ms)
# [ 770/1200] Uploading keywords_curated/up/up.0579.wav OK (324 ms)
# [ 771/1200] Uploading keywords_curated/up/up.1110.wav OK (321 ms)
# [ 772/1200] Uploading keywords_curated/up/up.0378.wav OK (343 ms)
# [ 773/1200] Uploading keywords_curated/up/up.0326.wav OK (339 ms)
# [ 774/1200] Uploading keywords_curated/up/up.0397.wav OK (365 ms)
# [ 775/1200] Uploading keywords_curated/up/up.1473.wav OK (333 ms)
# [ 776/1200] Uploading keywords_curated/up/up.0039.wav OK (405 ms)
# [ 777/1200] Uploading keywords_curated/up/up.0216.wav OK (334 ms)
# [ 778/1200] Uploading keywords_curated/up/up.1101.wav OK (322 ms)
# [ 779/1200] Uploading keywords_curated/up/up.0097.wav OK (294 ms)
# [ 780/1200] Uploading keywords_curated/up/up.1037.wav OK (290 ms)
# [ 781/1200] Uploading keywords_curated/up/up.0262.wav OK (232 ms)
# [ 782/1200] Uploading keywords_curated/up/up.0348.wav OK (382 ms)
# [ 783/1200] Uploading keywords_curated/up/up.1159.wav OK (373 ms)
# [ 784/1200] Uploading keywords_curated/up/up.1275.wav OK (319 ms)
# [ 785/1200] Uploading keywords_curated/up/up.1263.wav OK (335 ms)
# [ 786/1200] Uploading keywords_curated/up/up.0560.wav OK (338 ms)
# [ 787/1200] Uploading keywords_curated/up/up.0243.wav OK (365 ms)
# [ 788/1200] Uploading keywords_curated/up/up.1338.wav OK (345 ms)
# [ 789/1200] Uploading keywords_curated/up/up.0471.wav OK (299 ms)
# [ 790/1200] Uploading keywords_curated/up/up.1482.wav OK (346 ms)
# [ 791/1200] Uploading keywords_curated/up/up.0123.wav OK (269 ms)
# [ 792/1200] Uploading keywords_curated/up/up.0775.wav OK (365 ms)
# [ 793/1200] Uploading keywords_curated/up/up.0902.wav OK (249 ms)
# [ 794/1200] Uploading keywords_curated/up/up.0667.wav OK (320 ms)
# [ 795/1200] Uploading keywords_curated/up/up.0047.wav OK (343 ms)
# [ 796/1200] Uploading keywords_curated/up/up.1078.wav OK (280 ms)
# [ 797/1200] Uploading keywords_curated/up/up.0736.wav OK (433 ms)
# [ 798/1200] Uploading keywords_curated/up/up.0470.wav OK (340 ms)
# [ 799/1200] Uploading keywords_curated/up/up.0720.wav OK (425 ms)
# [ 800/1200] Uploading keywords_curated/up/up.0293.wav OK (346 ms)
# [ 801/1200] Uploading keywords_curated/up/up.0733.wav OK (479 ms)
# [ 802/1200] Uploading keywords_curated/up/up.0186.wav OK (298 ms)
# [ 803/1200] Uploading keywords_curated/up/up.0088.wav OK (280 ms)
# [ 804/1200] Uploading keywords_curated/up/up.0614.wav OK (262 ms)
# [ 805/1200] Uploading keywords_curated/up/up.0724.wav OK (302 ms)
# [ 806/1200] Uploading keywords_curated/up/up.0285.wav OK (316 ms)
# [ 807/1200] Uploading keywords_curated/up/up.0206.wav OK (321 ms)
# [ 808/1200] Uploading keywords_curated/up/up.0125.wav OK (356 ms)
# [ 809/1200] Uploading keywords_curated/up/up.0188.wav OK (373 ms)
# [ 810/1200] Uploading keywords_curated/up/up.0346.wav OK (322 ms)
# [ 811/1200] Uploading keywords_curated/up/up.1096.wav OK (266 ms)
# [ 812/1200] Uploading keywords_curated/up/up.1279.wav OK (392 ms)
# [ 813/1200] Uploading keywords_curated/up/up.1260.wav OK (338 ms)
# [ 814/1200] Uploading keywords_curated/up/up.0778.wav OK (330 ms)
# [ 815/1200] Uploading keywords_curated/up/up.0455.wav OK (312 ms)
# [ 816/1200] Uploading keywords_curated/up/up.0445.wav OK (421 ms)
# [ 817/1200] Uploading keywords_curated/up/up.0028.wav OK (416 ms)
# [ 818/1200] Uploading keywords_curated/up/up.1405.wav OK (360 ms)
# [ 819/1200] Uploading keywords_curated/up/up.0076.wav OK (284 ms)
# [ 820/1200] Uploading keywords_curated/up/up.0532.wav OK (310 ms)
# [ 821/1200] Uploading keywords_curated/up/up.1246.wav OK (330 ms)
# [ 822/1200] Uploading keywords_curated/up/up.1483.wav OK (478 ms)
# [ 823/1200] Uploading keywords_curated/up/up.0135.wav OK (368 ms)
# [ 824/1200] Uploading keywords_curated/up/up.1160.wav OK (293 ms)
# [ 825/1200] Uploading keywords_curated/up/up.0741.wav OK (357 ms)
# [ 826/1200] Uploading keywords_curated/up/up.0054.wav OK (553 ms)
# [ 827/1200] Uploading keywords_curated/up/up.0507.wav OK (428 ms)
# [ 828/1200] Uploading keywords_curated/up/up.1496.wav OK (328 ms)
# [ 829/1200] Uploading keywords_curated/up/up.0711.wav OK (297 ms)
# [ 830/1200] Uploading keywords_curated/up/up.0732.wav OK (354 ms)
# [ 831/1200] Uploading keywords_curated/up/up.1239.wav OK (380 ms)
# [ 832/1200] Uploading keywords_curated/up/up.1120.wav OK (352 ms)
# [ 833/1200] Uploading keywords_curated/up/up.0006.wav OK (333 ms)
# [ 834/1200] Uploading keywords_curated/up/up.1102.wav OK (320 ms)
# [ 835/1200] Uploading keywords_curated/up/up.0703.wav OK (371 ms)
# [ 836/1200] Uploading keywords_curated/up/up.0430.wav OK (330 ms)
# [ 837/1200] Uploading keywords_curated/up/up.0162.wav OK (429 ms)
# [ 838/1200] Uploading keywords_curated/up/up.0026.wav OK (324 ms)
# [ 839/1200] Uploading keywords_curated/up/up.0003.wav OK (309 ms)
# [ 840/1200] Uploading keywords_curated/up/up.0608.wav OK (302 ms)
# [ 841/1200] Uploading keywords_curated/up/up.0139.wav OK (341 ms)
# [ 842/1200] Uploading keywords_curated/up/up.0265.wav OK (271 ms)
# [ 843/1200] Uploading keywords_curated/up/up.0116.wav OK (491 ms)
# [ 844/1200] Uploading keywords_curated/up/up.0968.wav OK (295 ms)
# [ 845/1200] Uploading keywords_curated/up/up.1430.wav OK (498 ms)
# [ 846/1200] Uploading keywords_curated/up/up.0803.wav OK (398 ms)
# [ 847/1200] Uploading keywords_curated/up/up.1232.wav OK (326 ms)
# [ 848/1200] Uploading keywords_curated/up/up.1114.wav OK (288 ms)
# [ 849/1200] Uploading keywords_curated/up/up.0030.wav OK (268 ms)
# [ 850/1200] Uploading keywords_curated/up/up.0884.wav OK (303 ms)
# [ 851/1200] Uploading keywords_curated/up/up.1324.wav OK (323 ms)
# [ 852/1200] Uploading keywords_curated/up/up.0018.wav OK (328 ms)
# [ 853/1200] Uploading keywords_curated/up/up.1189.wav OK (342 ms)
# [ 854/1200] Uploading keywords_curated/up/up.0892.wav OK (357 ms)
# [ 855/1200] Uploading keywords_curated/up/up.0418.wav OK (458 ms)
# [ 856/1200] Uploading keywords_curated/up/up.0153.wav OK (414 ms)
# [ 857/1200] Uploading keywords_curated/up/up.0158.wav OK (493 ms)
# [ 858/1200] Uploading keywords_curated/up/up.1454.wav OK (278 ms)
# [ 859/1200] Uploading keywords_curated/up/up.0808.wav OK (298 ms)
# [ 860/1200] Uploading keywords_curated/up/up.0074.wav OK (369 ms)
# [ 861/1200] Uploading keywords_curated/up/up.1401.wav OK (330 ms)
# [ 862/1200] Uploading keywords_curated/up/up.1005.wav OK (380 ms)
# [ 863/1200] Uploading keywords_curated/up/up.0636.wav OK (330 ms)
# [ 864/1200] Uploading keywords_curated/up/up.0447.wav OK (275 ms)
# [ 865/1200] Uploading keywords_curated/up/up.0073.wav OK (275 ms)
# [ 866/1200] Uploading keywords_curated/up/up.0312.wav OK (351 ms)
# [ 867/1200] Uploading keywords_curated/up/up.0344.wav OK (263 ms)
# [ 868/1200] Uploading keywords_curated/up/up.0542.wav OK (387 ms)
# [ 869/1200] Uploading keywords_curated/up/up.0899.wav OK (308 ms)
# [ 870/1200] Uploading keywords_curated/up/up.0220.wav OK (385 ms)
# [ 871/1200] Uploading keywords_curated/up/up.0592.wav OK (296 ms)
# [ 872/1200] Uploading keywords_curated/up/up.1310.wav OK (404 ms)
# [ 873/1200] Uploading keywords_curated/up/up.0936.wav OK (329 ms)
# [ 874/1200] Uploading keywords_curated/up/up.0462.wav OK (411 ms)
# [ 875/1200] Uploading keywords_curated/up/up.0963.wav OK (392 ms)
# [ 876/1200] Uploading keywords_curated/up/up.0273.wav OK (287 ms)
# [ 877/1200] Uploading keywords_curated/up/up.0790.wav OK (387 ms)
# [ 878/1200] Uploading keywords_curated/up/up.0320.wav OK (387 ms)
# [ 879/1200] Uploading keywords_curated/up/up.0809.wav OK (316 ms)
# [ 880/1200] Uploading keywords_curated/up/up.0747.wav OK (354 ms)
# [ 881/1200] Uploading keywords_curated/up/up.1064.wav OK (490 ms)
# [ 882/1200] Uploading keywords_curated/up/up.0131.wav OK (319 ms)
# [ 883/1200] Uploading keywords_curated/up/up.0301.wav OK (293 ms)
# [ 884/1200] Uploading keywords_curated/up/up.0389.wav OK (317 ms)
# [ 885/1200] Uploading keywords_curated/up/up.0974.wav OK (351 ms)
# [ 886/1200] Uploading keywords_curated/up/up.0406.wav OK (266 ms)
# [ 887/1200] Uploading keywords_curated/up/up.0432.wav OK (307 ms)
# [ 888/1200] Uploading keywords_curated/up/up.0098.wav OK (362 ms)
# [ 889/1200] Uploading keywords_curated/up/up.0917.wav OK (362 ms)
# [ 890/1200] Uploading keywords_curated/up/up.1346.wav OK (469 ms)
# [ 891/1200] Uploading keywords_curated/up/up.0715.wav OK (285 ms)
# [ 892/1200] Uploading keywords_curated/up/up.0362.wav OK (271 ms)
# [ 893/1200] Uploading keywords_curated/up/up.1438.wav OK (508 ms)
# [ 894/1200] Uploading keywords_curated/up/up.0982.wav OK (353 ms)
# [ 895/1200] Uploading keywords_curated/up/up.1074.wav OK (312 ms)
# [ 896/1200] Uploading keywords_curated/up/up.1192.wav OK (348 ms)
# [ 897/1200] Uploading keywords_curated/up/up.0994.wav OK (240 ms)
# [ 898/1200] Uploading keywords_curated/up/up.0476.wav OK (371 ms)
# [ 899/1200] Uploading keywords_curated/up/up.0845.wav OK (393 ms)
# [ 900/1200] Uploading keywords_curated/up/up.1061.wav OK (356 ms)
# [ 901/1200] Uploading keywords_curated/up/up.0307.wav OK (392 ms)
# [ 902/1200] Uploading keywords_curated/up/up.0199.wav OK (344 ms)
# [ 903/1200] Uploading keywords_curated/up/up.0393.wav OK (312 ms)
# [ 904/1200] Uploading keywords_curated/up/up.1283.wav OK (302 ms)
# [ 905/1200] Uploading keywords_curated/up/up.1054.wav OK (288 ms)
# [ 906/1200] Uploading keywords_curated/up/up.1107.wav OK (352 ms)
# [ 907/1200] Uploading keywords_curated/up/up.1426.wav OK (344 ms)
# [ 908/1200] Uploading keywords_curated/up/up.0434.wav OK (330 ms)
# [ 909/1200] Uploading keywords_curated/up/up.0080.wav OK (303 ms)
# [ 910/1200] Uploading keywords_curated/up/up.0195.wav OK (319 ms)
# [ 911/1200] Uploading keywords_curated/up/up.0438.wav OK (270 ms)
# [ 912/1200] Uploading keywords_curated/up/up.0364.wav OK (390 ms)
# [ 913/1200] Uploading keywords_curated/up/up.0977.wav OK (386 ms)
# [ 914/1200] Uploading keywords_curated/up/up.0021.wav OK (309 ms)
# [ 915/1200] Uploading keywords_curated/up/up.0454.wav OK (314 ms)
# [ 916/1200] Uploading keywords_curated/up/up.0754.wav OK (361 ms)
# [ 917/1200] Uploading keywords_curated/up/up.0404.wav OK (294 ms)
# [ 918/1200] Uploading keywords_curated/up/up.1012.wav OK (326 ms)
# [ 919/1200] Uploading keywords_curated/up/up.1001.wav OK (620 ms)
# [ 920/1200] Uploading keywords_curated/up/up.0612.wav OK (305 ms)
# [ 921/1200] Uploading keywords_curated/up/up.1223.wav OK (314 ms)
# [ 922/1200] Uploading keywords_curated/up/up.1354.wav OK (330 ms)
# [ 923/1200] Uploading keywords_curated/up/up.1076.wav OK (285 ms)
# [ 924/1200] Uploading keywords_curated/up/up.1385.wav OK (306 ms)
# [ 925/1200] Uploading keywords_curated/up/up.0813.wav OK (335 ms)
# [ 926/1200] Uploading keywords_curated/up/up.0638.wav OK (370 ms)
# [ 927/1200] Uploading keywords_curated/up/up.0405.wav OK (322 ms)
# [ 928/1200] Uploading keywords_curated/up/up.0479.wav OK (298 ms)
# [ 929/1200] Uploading keywords_curated/up/up.1002.wav OK (362 ms)
# [ 930/1200] Uploading keywords_curated/up/up.0031.wav OK (355 ms)
# [ 931/1200] Uploading keywords_curated/up/up.0524.wav OK (308 ms)
# [ 932/1200] Uploading keywords_curated/up/up.0556.wav OK (304 ms)
# [ 933/1200] Uploading keywords_curated/up/up.1203.wav OK (384 ms)
# [ 934/1200] Uploading keywords_curated/up/up.0093.wav OK (345 ms)
# [ 935/1200] Uploading keywords_curated/up/up.0215.wav OK (363 ms)
# [ 936/1200] Uploading keywords_curated/up/up.1186.wav OK (262 ms)
# [ 937/1200] Uploading keywords_curated/up/up.0942.wav OK (367 ms)
# [ 938/1200] Uploading keywords_curated/up/up.0032.wav OK (309 ms)
# [ 939/1200] Uploading keywords_curated/up/up.0587.wav OK (382 ms)
# [ 940/1200] Uploading keywords_curated/up/up.1422.wav OK (395 ms)
# [ 941/1200] Uploading keywords_curated/up/up.0170.wav OK (270 ms)
# [ 942/1200] Uploading keywords_curated/up/up.1451.wav OK (287 ms)
# [ 943/1200] Uploading keywords_curated/up/up.1317.wav OK (313 ms)
# [ 944/1200] Uploading keywords_curated/up/up.1171.wav OK (334 ms)
# [ 945/1200] Uploading keywords_curated/up/up.1111.wav OK (281 ms)
# [ 946/1200] Uploading keywords_curated/up/up.1403.wav OK (354 ms)
# [ 947/1200] Uploading keywords_curated/up/up.0866.wav OK (303 ms)
# [ 948/1200] Uploading keywords_curated/up/up.0880.wav OK (355 ms)
# [ 949/1200] Uploading keywords_curated/up/up.0602.wav OK (294 ms)
# [ 950/1200] Uploading keywords_curated/up/up.1498.wav OK (294 ms)
# [ 951/1200] Uploading keywords_curated/up/up.0907.wav OK (351 ms)
# [ 952/1200] Uploading keywords_curated/up/up.1411.wav OK (351 ms)
# [ 953/1200] Uploading keywords_curated/up/up.0209.wav OK (315 ms)
# [ 954/1200] Uploading keywords_curated/up/up.1457.wav OK (317 ms)
# [ 955/1200] Uploading keywords_curated/up/up.0679.wav OK (397 ms)
# [ 956/1200] Uploading keywords_curated/up/up.1017.wav OK (282 ms)
# [ 957/1200] Uploading keywords_curated/up/up.1264.wav OK (456 ms)
# [ 958/1200] Uploading keywords_curated/up/up.0805.wav OK (505 ms)
# [ 959/1200] Uploading keywords_curated/up/up.0757.wav OK (317 ms)
# [ 960/1200] Uploading keywords_curated/up/up.0894.wav OK (470 ms)
# [ 961/1200] Uploading keywords_curated/up/up.0926.wav OK (455 ms)
# [ 962/1200] Uploading keywords_curated/up/up.0865.wav OK (315 ms)
# [ 963/1200] Uploading keywords_curated/up/up.0155.wav OK (265 ms)
# [ 964/1200] Uploading keywords_curated/up/up.0299.wav OK (328 ms)
# [ 965/1200] Uploading keywords_curated/up/up.0270.wav OK (425 ms)
# [ 966/1200] Uploading keywords_curated/up/up.0829.wav OK (277 ms)
# [ 967/1200] Uploading keywords_curated/up/up.0594.wav OK (458 ms)
# [ 968/1200] Uploading keywords_curated/up/up.0383.wav OK (543 ms)
# [ 969/1200] Uploading keywords_curated/up/up.0984.wav OK (404 ms)
# [ 970/1200] Uploading keywords_curated/up/up.0002.wav OK (366 ms)
# [ 971/1200] Uploading keywords_curated/up/up.1046.wav OK (456 ms)
# [ 972/1200] Uploading keywords_curated/up/up.1200.wav OK (444 ms)
# [ 973/1200] Uploading keywords_curated/up/up.1321.wav OK (426 ms)
# [ 974/1200] Uploading keywords_curated/up/up.1296.wav OK (299 ms)
# [ 975/1200] Uploading keywords_curated/up/up.0657.wav OK (356 ms)
# [ 976/1200] Uploading keywords_curated/up/up.1148.wav OK (346 ms)
# [ 977/1200] Uploading keywords_curated/up/up.1316.wav OK (335 ms)
# [ 978/1200] Uploading keywords_curated/up/up.1077.wav OK (475 ms)
# [ 979/1200] Uploading keywords_curated/up/up.0909.wav OK (403 ms)
# [ 980/1200] Uploading keywords_curated/up/up.0550.wav OK (494 ms)
# [ 981/1200] Uploading keywords_curated/up/up.0370.wav OK (382 ms)
# [ 982/1200] Uploading keywords_curated/up/up.1440.wav OK (388 ms)
# [ 983/1200] Uploading keywords_curated/up/up.0469.wav OK (370 ms)
# [ 984/1200] Uploading keywords_curated/up/up.1330.wav OK (327 ms)
# [ 985/1200] Uploading keywords_curated/up/up.0749.wav OK (303 ms)
# [ 986/1200] Uploading keywords_curated/up/up.0927.wav OK (406 ms)
# [ 987/1200] Uploading keywords_curated/up/up.0248.wav OK (419 ms)
# [ 988/1200] Uploading keywords_curated/up/up.0569.wav OK (312 ms)
# [ 989/1200] Uploading keywords_curated/up/up.1167.wav OK (332 ms)
# [ 990/1200] Uploading keywords_curated/up/up.1070.wav OK (295 ms)
# [ 991/1200] Uploading keywords_curated/up/up.1469.wav OK (294 ms)
# [ 992/1200] Uploading keywords_curated/up/up.0340.wav OK (439 ms)
# [ 993/1200] Uploading keywords_curated/up/up.0484.wav OK (356 ms)
# [ 994/1200] Uploading keywords_curated/up/up.0253.wav OK (278 ms)
# [ 995/1200] Uploading keywords_curated/up/up.0886.wav OK (296 ms)
# [ 996/1200] Uploading keywords_curated/up/up.1479.wav OK (278 ms)
# [ 997/1200] Uploading keywords_curated/up/up.0246.wav OK (420 ms)
# [ 998/1200] Uploading keywords_curated/up/up.0264.wav OK (313 ms)
# [ 999/1200] Uploading keywords_curated/up/up.0235.wav OK (434 ms)
# [1000/1200] Uploading keywords_curated/up/up.0077.wav OK (446 ms)
# [1001/1200] Uploading keywords_curated/up/up.0451.wav OK (467 ms)
# [1002/1200] Uploading keywords_curated/up/up.1154.wav OK (435 ms)
# [1003/1200] Uploading keywords_curated/up/up.0868.wav OK (332 ms)
# [1004/1200] Uploading keywords_curated/up/up.0072.wav OK (268 ms)
# [1005/1200] Uploading keywords_curated/up/up.1211.wav OK (255 ms)
# [1006/1200] Uploading keywords_curated/up/up.1392.wav OK (325 ms)
# [1007/1200] Uploading keywords_curated/up/up.1109.wav OK (409 ms)
# [1008/1200] Uploading keywords_curated/up/up.1291.wav OK (435 ms)
# [1009/1200] Uploading keywords_curated/up/up.0448.wav OK (298 ms)
# [1010/1200] Uploading keywords_curated/up/up.1043.wav OK (269 ms)
# [1011/1200] Uploading keywords_curated/up/up.1184.wav OK (363 ms)
# [1012/1200] Uploading keywords_curated/up/up.0800.wav OK (386 ms)
# [1013/1200] Uploading keywords_curated/up/up.0590.wav OK (308 ms)
# [1014/1200] Uploading keywords_curated/up/up.1284.wav OK (329 ms)
# [1015/1200] Uploading keywords_curated/up/up.0306.wav OK (365 ms)
# [1016/1200] Uploading keywords_curated/up/up.1305.wav OK (354 ms)
# [1017/1200] Uploading keywords_curated/up/up.1040.wav OK (270 ms)
# [1018/1200] Uploading keywords_curated/up/up.0040.wav OK (398 ms)
# [1019/1200] Uploading keywords_curated/up/up.0979.wav OK (352 ms)
# [1020/1200] Uploading keywords_curated/up/up.0503.wav OK (322 ms)
# [1021/1200] Uploading keywords_curated/up/up.1467.wav OK (399 ms)
# [1022/1200] Uploading keywords_curated/up/up.0601.wav OK (270 ms)
# [1023/1200] Uploading keywords_curated/up/up.0721.wav OK (359 ms)
# [1024/1200] Uploading keywords_curated/up/up.0547.wav OK (311 ms)
# [1025/1200] Uploading keywords_curated/up/up.0642.wav OK (252 ms)
# [1026/1200] Uploading keywords_curated/up/up.0122.wav OK (477 ms)
# [1027/1200] Uploading keywords_curated/up/up.0166.wav OK (268 ms)
# [1028/1200] Uploading keywords_curated/up/up.0990.wav OK (410 ms)
# [1029/1200] Uploading keywords_curated/up/up.0563.wav OK (272 ms)
# [1030/1200] Uploading keywords_curated/up/up.0606.wav OK (374 ms)
# [1031/1200] Uploading keywords_curated/up/up.1136.wav OK (334 ms)
# [1032/1200] Uploading keywords_curated/up/up.0705.wav OK (241 ms)
# [1033/1200] Uploading keywords_curated/up/up.1273.wav OK (377 ms)
# [1034/1200] Uploading keywords_curated/up/up.1255.wav OK (343 ms)
# [1035/1200] Uploading keywords_curated/up/up.0374.wav OK (334 ms)
# [1036/1200] Uploading keywords_curated/up/up.1055.wav OK (318 ms)
# [1037/1200] Uploading keywords_curated/up/up.0474.wav OK (357 ms)
# [1038/1200] Uploading keywords_curated/up/up.0582.wav OK (401 ms)
# [1039/1200] Uploading keywords_curated/up/up.0226.wav OK (373 ms)
# [1040/1200] Uploading keywords_curated/up/up.0350.wav OK (310 ms)
# [1041/1200] Uploading keywords_curated/up/up.1042.wav OK (276 ms)
# [1042/1200] Uploading keywords_curated/up/up.0682.wav OK (378 ms)
# [1043/1200] Uploading keywords_curated/up/up.0546.wav OK (389 ms)
# [1044/1200] Uploading keywords_curated/up/up.0431.wav OK (409 ms)
# [1045/1200] Uploading keywords_curated/up/up.0491.wav OK (366 ms)
# [1046/1200] Uploading keywords_curated/up/up.0075.wav OK (431 ms)
# [1047/1200] Uploading keywords_curated/up/up.0916.wav OK (427 ms)
# [1048/1200] Uploading keywords_curated/up/up.0316.wav OK (293 ms)
# [1049/1200] Uploading keywords_curated/up/up.0142.wav OK (342 ms)
# [1050/1200] Uploading keywords_curated/up/up.0012.wav OK (352 ms)
# [1051/1200] Uploading keywords_curated/up/up.0735.wav OK (280 ms)
# [1052/1200] Uploading keywords_curated/up/up.1278.wav OK (269 ms)
# [1053/1200] Uploading keywords_curated/up/up.0983.wav OK (294 ms)
# [1054/1200] Uploading keywords_curated/up/up.0585.wav OK (286 ms)
# [1055/1200] Uploading keywords_curated/up/up.1266.wav OK (279 ms)
# [1056/1200] Uploading keywords_curated/up/up.1029.wav OK (274 ms)
# [1057/1200] Uploading keywords_curated/up/up.1097.wav OK (301 ms)
# [1058/1200] Uploading keywords_curated/up/up.1408.wav OK (281 ms)
# [1059/1200] Uploading keywords_curated/up/up.0519.wav OK (322 ms)
# [1060/1200] Uploading keywords_curated/up/up.1464.wav OK (285 ms)
# [1061/1200] Uploading keywords_curated/up/up.0437.wav OK (274 ms)
# [1062/1200] Uploading keywords_curated/up/up.0274.wav OK (406 ms)
# [1063/1200] Uploading keywords_curated/up/up.1087.wav OK (459 ms)
# [1064/1200] Uploading keywords_curated/up/up.0962.wav OK (454 ms)
# [1065/1200] Uploading keywords_curated/up/up.0919.wav OK (482 ms)
# [1066/1200] Uploading keywords_curated/up/up.1007.wav OK (424 ms)
# [1067/1200] Uploading keywords_curated/up/up.1065.wav OK (316 ms)
# [1068/1200] Uploading keywords_curated/up/up.1303.wav OK (507 ms)
# [1069/1200] Uploading keywords_curated/up/up.1199.wav OK (555 ms)
# [1070/1200] Uploading keywords_curated/up/up.0680.wav OK (271 ms)
# [1071/1200] Uploading keywords_curated/up/up.1358.wav OK (519 ms)
# [1072/1200] Uploading keywords_curated/up/up.0436.wav OK (245 ms)
# [1073/1200] Uploading keywords_curated/up/up.1019.wav OK (333 ms)
# [1074/1200] Uploading keywords_curated/up/up.1334.wav OK (461 ms)
# [1075/1200] Uploading keywords_curated/up/up.1302.wav OK (351 ms)
# [1076/1200] Uploading keywords_curated/up/up.0684.wav OK (309 ms)
# [1077/1200] Uploading keywords_curated/up/up.1014.wav OK (291 ms)
# [1078/1200] Uploading keywords_curated/up/up.0714.wav OK (304 ms)
# [1079/1200] Uploading keywords_curated/up/up.0289.wav OK (359 ms)
# [1080/1200] Uploading keywords_curated/up/up.0177.wav OK (299 ms)
# [1081/1200] Uploading keywords_curated/up/up.0058.wav OK (304 ms)
# [1082/1200] Uploading keywords_curated/up/up.0707.wav OK (346 ms)
# [1083/1200] Uploading keywords_curated/up/up.0161.wav OK (356 ms)
# [1084/1200] Uploading keywords_curated/up/up.1127.wav OK (295 ms)
# [1085/1200] Uploading keywords_curated/up/up.0988.wav OK (692 ms)
# [1086/1200] Uploading keywords_curated/up/up.0231.wav OK (326 ms)
# [1087/1200] Uploading keywords_curated/up/up.1090.wav OK (379 ms)
# [1088/1200] Uploading keywords_curated/up/up.0449.wav OK (339 ms)
# [1089/1200] Uploading keywords_curated/up/up.0624.wav OK (257 ms)
# [1090/1200] Uploading keywords_curated/up/up.0912.wav OK (380 ms)
# [1091/1200] Uploading keywords_curated/up/up.0734.wav OK (373 ms)
# [1092/1200] Uploading keywords_curated/up/up.1144.wav OK (355 ms)
# [1093/1200] Uploading keywords_curated/up/up.0687.wav OK (393 ms)
# [1094/1200] Uploading keywords_curated/up/up.0658.wav OK (363 ms)
# [1095/1200] Uploading keywords_curated/up/up.0985.wav OK (402 ms)
# [1096/1200] Uploading keywords_curated/up/up.0643.wav OK (324 ms)
# [1097/1200] Uploading keywords_curated/up/up.1153.wav OK (275 ms)
# [1098/1200] Uploading keywords_curated/up/up.0529.wav OK (285 ms)
# [1099/1200] Uploading keywords_curated/up/up.0130.wav OK (297 ms)
# [1100/1200] Uploading keywords_curated/up/up.0327.wav OK (319 ms)
# [1101/1200] Uploading keywords_curated/up/up.1348.wav OK (274 ms)
# [1102/1200] Uploading keywords_curated/up/up.0600.wav OK (352 ms)
# [1103/1200] Uploading keywords_curated/up/up.0549.wav OK (296 ms)
# [1104/1200] Uploading keywords_curated/up/up.1381.wav OK (377 ms)
# [1105/1200] Uploading keywords_curated/up/up.0104.wav OK (278 ms)
# [1106/1200] Uploading keywords_curated/up/up.0967.wav OK (313 ms)
# [1107/1200] Uploading keywords_curated/up/up.0662.wav OK (292 ms)
# [1108/1200] Uploading keywords_curated/up/up.0439.wav OK (318 ms)
# [1109/1200] Uploading keywords_curated/up/up.1363.wav OK (357 ms)
# [1110/1200] Uploading keywords_curated/up/up.0272.wav OK (349 ms)
# [1111/1200] Uploading keywords_curated/up/up.0502.wav OK (424 ms)
# [1112/1200] Uploading keywords_curated/up/up.0597.wav OK (317 ms)
# [1113/1200] Uploading keywords_curated/up/up.0041.wav OK (361 ms)
# [1114/1200] Uploading keywords_curated/up/up.0203.wav OK (381 ms)
# [1115/1200] Uploading keywords_curated/up/up.0381.wav OK (378 ms)
# [1116/1200] Uploading keywords_curated/up/up.0853.wav OK (371 ms)
# [1117/1200] Uploading keywords_curated/up/up.1217.wav OK (324 ms)
# [1118/1200] Uploading keywords_curated/up/up.1297.wav OK (355 ms)
# [1119/1200] Uploading keywords_curated/up/up.1374.wav OK (348 ms)
# [1120/1200] Uploading keywords_curated/up/up.0233.wav OK (326 ms)
# [1121/1200] Uploading keywords_curated/up/up.1396.wav OK (231 ms)
# [1122/1200] Uploading keywords_curated/up/up.0941.wav OK (355 ms)
# [1123/1200] Uploading keywords_curated/up/up.0860.wav OK (372 ms)
# [1124/1200] Uploading keywords_curated/up/up.0239.wav OK (244 ms)
# [1125/1200] Uploading keywords_curated/up/up.0052.wav OK (345 ms)
# [1126/1200] Uploading keywords_curated/up/up.0493.wav OK (239 ms)
# [1127/1200] Uploading keywords_curated/up/up.0034.wav OK (287 ms)
# [1128/1200] Uploading keywords_curated/up/up.1215.wav OK (399 ms)
# [1129/1200] Uploading keywords_curated/up/up.0036.wav OK (335 ms)
# [1130/1200] Uploading keywords_curated/up/up.1360.wav OK (258 ms)
# [1131/1200] Uploading keywords_curated/up/up.0882.wav OK (303 ms)
# [1132/1200] Uploading keywords_curated/up/up.1212.wav OK (393 ms)
# [1133/1200] Uploading keywords_curated/up/up.1170.wav OK (339 ms)
# [1134/1200] Uploading keywords_curated/up/up.0728.wav OK (238 ms)
# [1135/1200] Uploading keywords_curated/up/up.0061.wav OK (271 ms)
# [1136/1200] Uploading keywords_curated/up/up.1326.wav OK (343 ms)
# [1137/1200] Uploading keywords_curated/up/up.1308.wav OK (511 ms)
# [1138/1200] Uploading keywords_curated/up/up.0138.wav OK (268 ms)
# [1139/1200] Uploading keywords_curated/up/up.1359.wav OK (448 ms)
# [1140/1200] Uploading keywords_curated/up/up.0302.wav OK (419 ms)
# [1141/1200] Uploading keywords_curated/up/up.0966.wav OK (487 ms)
# [1142/1200] Uploading keywords_curated/up/up.0341.wav OK (237 ms)
# [1143/1200] Uploading keywords_curated/up/up.1134.wav OK (293 ms)
# [1144/1200] Uploading keywords_curated/up/up.0300.wav OK (566 ms)
# [1145/1200] Uploading keywords_curated/up/up.0087.wav OK (521 ms)
# [1146/1200] Uploading keywords_curated/up/up.1306.wav OK (468 ms)
# [1147/1200] Uploading keywords_curated/up/up.0978.wav OK (575 ms)
# [1148/1200] Uploading keywords_curated/up/up.1177.wav OK (560 ms)
# [1149/1200] Uploading keywords_curated/up/up.1121.wav OK (544 ms)
# [1150/1200] Uploading keywords_curated/up/up.0443.wav OK (311 ms)
# [1151/1200] Uploading keywords_curated/up/up.0118.wav OK (315 ms)
# [1152/1200] Uploading keywords_curated/up/up.1494.wav OK (274 ms)
# [1153/1200] Uploading keywords_curated/up/up.0360.wav OK (324 ms)
# [1154/1200] Uploading keywords_curated/up/up.0288.wav OK (302 ms)
# [1155/1200] Uploading keywords_curated/up/up.0878.wav OK (300 ms)
# [1156/1200] Uploading keywords_curated/up/up.1409.wav OK (294 ms)
# [1157/1200] Uploading keywords_curated/up/up.0965.wav OK (279 ms)
# [1158/1200] Uploading keywords_curated/up/up.1265.wav OK (326 ms)
# [1159/1200] Uploading keywords_curated/up/up.0855.wav OK (432 ms)
# [1160/1200] Uploading keywords_curated/up/up.0279.wav OK (348 ms)
# [1161/1200] Uploading keywords_curated/up/up.1226.wav OK (326 ms)
# [1162/1200] Uploading keywords_curated/up/up.1294.wav OK (317 ms)
# [1163/1200] Uploading keywords_curated/up/up.0545.wav OK (330 ms)
# [1164/1200] Uploading keywords_curated/up/up.1413.wav OK (313 ms)
# [1165/1200] Uploading keywords_curated/up/up.0595.wav OK (352 ms)
# [1166/1200] Uploading keywords_curated/up/up.0180.wav OK (336 ms)
# [1167/1200] Uploading keywords_curated/up/up.1122.wav OK (343 ms)
# [1168/1200] Uploading keywords_curated/up/up.0932.wav OK (363 ms)
# [1169/1200] Uploading keywords_curated/up/up.0499.wav OK (338 ms)
# [1170/1200] Uploading keywords_curated/up/up.1242.wav OK (377 ms)
# [1171/1200] Uploading keywords_curated/up/up.0422.wav OK (313 ms)
# [1172/1200] Uploading keywords_curated/up/up.0297.wav OK (327 ms)
# [1173/1200] Uploading keywords_curated/up/up.0391.wav OK (392 ms)
# [1174/1200] Uploading keywords_curated/up/up.1062.wav OK (366 ms)
# [1175/1200] Uploading keywords_curated/up/up.0165.wav OK (257 ms)
# [1176/1200] Uploading keywords_curated/up/up.1388.wav OK (341 ms)
# [1177/1200] Uploading keywords_curated/up/up.1259.wav OK (297 ms)
# [1178/1200] Uploading keywords_curated/up/up.1035.wav OK (448 ms)
# [1179/1200] Uploading keywords_curated/up/up.0287.wav OK (346 ms)
# [1180/1200] Uploading keywords_curated/up/up.0712.wav OK (300 ms)
# [1181/1200] Uploading keywords_curated/up/up.0468.wav OK (270 ms)
# [1182/1200] Uploading keywords_curated/up/up.0167.wav OK (347 ms)
# [1183/1200] Uploading keywords_curated/up/up.0062.wav OK (419 ms)
# [1184/1200] Uploading keywords_curated/up/up.1345.wav OK (417 ms)
# [1185/1200] Uploading keywords_curated/up/up.0038.wav OK (275 ms)
# [1186/1200] Uploading keywords_curated/up/up.1117.wav OK (299 ms)
# [1187/1200] Uploading keywords_curated/up/up.1116.wav OK (270 ms)
# [1188/1200] Uploading keywords_curated/up/up.1397.wav OK (345 ms)
# [1189/1200] Uploading keywords_curated/up/up.0394.wav OK (366 ms)
# [1190/1200] Uploading keywords_curated/up/up.0452.wav OK (300 ms)
# [1191/1200] Uploading keywords_curated/up/up.1414.wav OK (252 ms)
# [1192/1200] Uploading keywords_curated/up/up.0991.wav OK (372 ms)
# [1193/1200] Uploading keywords_curated/up/up.0825.wav OK (301 ms)
# [1194/1200] Uploading keywords_curated/up/up.1267.wav OK (301 ms)
# [1195/1200] Uploading keywords_curated/up/up.1470.wav OK (405 ms)
# [1196/1200] Uploading keywords_curated/up/up.1115.wav OK (288 ms)
# [1197/1200] Uploading keywords_curated/up/up.0652.wav OK (304 ms)
# [1198/1200] Uploading keywords_curated/up/up.1477.wav OK (321 ms)
# [1199/1200] Uploading keywords_curated/up/up.0056.wav OK (283 ms)
# [1200/1200] Uploading keywords_curated/up/up.0931.wav OK (348 ms)
# [  1/300] Uploading keywords_curated/goodnight/goodnight.1089.wav OK (694 ms)
# [  2/300] Uploading keywords_curated/goodnight/goodnight.0353.wav OK (696 ms)
# [  3/300] Uploading keywords_curated/goodnight/goodnight.1190.wav OK (742 ms)
# [  4/300] Uploading keywords_curated/goodnight/goodnight.1412.wav OK (813 ms)
# [  5/300] Uploading keywords_curated/goodnight/goodnight.0362.wav OK (822 ms)
# [  6/300] Uploading keywords_curated/goodnight/goodnight.0646.wav OK (843 ms)
# [  7/300] Uploading keywords_curated/goodnight/goodnight.0366.wav OK (845 ms)
# [  8/300] Uploading keywords_curated/goodnight/goodnight.0425.wav OK (861 ms)
# [  9/300] Uploading keywords_curated/goodnight/goodnight.0015.wav OK (874 ms)
# [ 10/300] Uploading keywords_curated/goodnight/goodnight.0833.wav OK (883 ms)
# [ 11/300] Uploading keywords_curated/goodnight/goodnight.0306.wav OK (885 ms)
# [ 12/300] Uploading keywords_curated/goodnight/goodnight.0257.wav OK (889 ms)
# [ 13/300] Uploading keywords_curated/goodnight/goodnight.0741.wav OK (926 ms)
# [ 14/300] Uploading keywords_curated/goodnight/goodnight.0832.wav OK (928 ms)
# [ 15/300] Uploading keywords_curated/goodnight/goodnight.1307.wav OK (935 ms)
# [ 16/300] Uploading keywords_curated/goodnight/goodnight.1447.wav OK (261 ms)
# [ 17/300] Uploading keywords_curated/goodnight/goodnight.0658.wav OK (314 ms)
# [ 18/300] Uploading keywords_curated/goodnight/goodnight.0711.wav OK (315 ms)
# [ 19/300] Uploading keywords_curated/goodnight/goodnight.0516.wav OK (398 ms)
# [ 20/300] Uploading keywords_curated/goodnight/goodnight.0712.wav OK (461 ms)
# [ 21/300] Uploading keywords_curated/goodnight/goodnight.1088.wav OK (493 ms)
# [ 22/300] Uploading keywords_curated/goodnight/goodnight.0673.wav OK (373 ms)
# [ 23/300] Uploading keywords_curated/goodnight/goodnight.0971.wav OK (332 ms)
# [ 24/300] Uploading keywords_curated/goodnight/goodnight.0095.wav OK (424 ms)
# [ 25/300] Uploading keywords_curated/goodnight/goodnight.0667.wav OK (483 ms)
# [ 26/300] Uploading keywords_curated/goodnight/goodnight.0662.wav OK (479 ms)
# [ 27/300] Uploading keywords_curated/goodnight/goodnight.1456.wav OK (520 ms)
# [ 28/300] Uploading keywords_curated/goodnight/goodnight.0090.wav OK (1373 ms)
# [ 29/300] Uploading keywords_curated/goodnight/goodnight.0222.wav OK (1382 ms)
# [ 30/300] Uploading keywords_curated/goodnight/goodnight.1159.wav OK (523 ms)
# [ 31/300] Uploading keywords_curated/goodnight/goodnight.0787.wav OK (1388 ms)
# [ 32/300] Uploading keywords_curated/goodnight/goodnight.1189.wav OK (1394 ms)
# [ 33/300] Uploading keywords_curated/goodnight/goodnight.1342.wav OK (551 ms)
# [ 34/300] Uploading keywords_curated/goodnight/goodnight.0883.wav OK (531 ms)
# [ 35/300] Uploading keywords_curated/goodnight/goodnight.0294.wav OK (371 ms)
# [ 36/300] Uploading keywords_curated/goodnight/goodnight.1420.wav OK (539 ms)
# [ 37/300] Uploading keywords_curated/goodnight/goodnight.0358.wav OK (549 ms)
# [ 38/300] Uploading keywords_curated/goodnight/goodnight.0591.wav OK (1476 ms)
# [ 39/300] Uploading keywords_curated/goodnight/goodnight.0684.wav OK (278 ms)
# [ 40/300] Uploading keywords_curated/goodnight/goodnight.0021.wav OK (317 ms)
# [ 41/300] Uploading keywords_curated/goodnight/goodnight.0558.wav OK (404 ms)
# [ 42/300] Uploading keywords_curated/goodnight/goodnight.0088.wav OK (431 ms)
# [ 43/300] Uploading keywords_curated/goodnight/goodnight.0227.wav OK (391 ms)
# [ 44/300] Uploading keywords_curated/goodnight/goodnight.1488.wav OK (423 ms)
# [ 45/300] Uploading keywords_curated/goodnight/goodnight.0997.wav OK (524 ms)
# [ 46/300] Uploading keywords_curated/goodnight/goodnight.1103.wav OK (431 ms)
# [ 47/300] Uploading keywords_curated/goodnight/goodnight.0256.wav OK (412 ms)
# [ 48/300] Uploading keywords_curated/goodnight/goodnight.1265.wav OK (488 ms)
# [ 49/300] Uploading keywords_curated/goodnight/goodnight.1003.wav OK (541 ms)
# [ 50/300] Uploading keywords_curated/goodnight/goodnight.1441.wav OK (538 ms)
# [ 51/300] Uploading keywords_curated/goodnight/goodnight.1208.wav OK (537 ms)
# [ 52/300] Uploading keywords_curated/goodnight/goodnight.0559.wav OK (582 ms)
# [ 53/300] Uploading keywords_curated/goodnight/goodnight.0125.wav OK (469 ms)
# [ 54/300] Uploading keywords_curated/goodnight/goodnight.0111.wav OK (283 ms)
# [ 55/300] Uploading keywords_curated/goodnight/goodnight.0553.wav OK (374 ms)
# [ 56/300] Uploading keywords_curated/goodnight/goodnight.1048.wav OK (607 ms)
# [ 57/300] Uploading keywords_curated/goodnight/goodnight.0838.wav OK (635 ms)
# [ 58/300] Uploading keywords_curated/goodnight/goodnight.1261.wav OK (347 ms)
# [ 59/300] Uploading keywords_curated/goodnight/goodnight.1460.wav OK (535 ms)
# [ 60/300] Uploading keywords_curated/goodnight/goodnight.0228.wav OK (590 ms)
# [ 61/300] Uploading keywords_curated/goodnight/goodnight.1320.wav OK (555 ms)
# [ 62/300] Uploading keywords_curated/goodnight/goodnight.0992.wav OK (298 ms)
# [ 63/300] Uploading keywords_curated/goodnight/goodnight.1166.wav OK (335 ms)
# [ 64/300] Uploading keywords_curated/goodnight/goodnight.0636.wav OK (283 ms)
# [ 65/300] Uploading keywords_curated/goodnight/goodnight.0631.wav OK (476 ms)
# [ 66/300] Uploading keywords_curated/goodnight/goodnight.1352.wav OK (280 ms)
# [ 67/300] Uploading keywords_curated/goodnight/goodnight.1202.wav OK (442 ms)
# [ 68/300] Uploading keywords_curated/goodnight/goodnight.1388.wav OK (266 ms)
# [ 69/300] Uploading keywords_curated/goodnight/goodnight.0612.wav OK (483 ms)
# [ 70/300] Uploading keywords_curated/goodnight/goodnight.0812.wav OK (314 ms)
# [ 71/300] Uploading keywords_curated/goodnight/goodnight.0504.wav OK (395 ms)
# [ 72/300] Uploading keywords_curated/goodnight/goodnight.0884.wav OK (456 ms)
# [ 73/300] Uploading keywords_curated/goodnight/goodnight.1100.wav OK (428 ms)
# [ 74/300] Uploading keywords_curated/goodnight/goodnight.0914.wav OK (438 ms)
# [ 75/300] Uploading keywords_curated/goodnight/goodnight.1078.wav OK (468 ms)
# [ 76/300] Uploading keywords_curated/goodnight/goodnight.1340.wav OK (311 ms)
# [ 77/300] Uploading keywords_curated/goodnight/goodnight.1235.wav OK (497 ms)
# [ 78/300] Uploading keywords_curated/goodnight/goodnight.0635.wav OK (451 ms)
# [ 79/300] Uploading keywords_curated/goodnight/goodnight.0163.wav OK (558 ms)
# [ 80/300] Uploading keywords_curated/goodnight/goodnight.1302.wav OK (277 ms)
# [ 81/300] Uploading keywords_curated/goodnight/goodnight.1179.wav OK (548 ms)
# [ 82/300] Uploading keywords_curated/goodnight/goodnight.1041.wav OK (439 ms)
# [ 83/300] Uploading keywords_curated/goodnight/goodnight.0580.wav OK (595 ms)
# [ 84/300] Uploading keywords_curated/goodnight/goodnight.0953.wav OK (566 ms)
# [ 85/300] Uploading keywords_curated/goodnight/goodnight.1270.wav OK (394 ms)
# [ 86/300] Uploading keywords_curated/goodnight/goodnight.0872.wav OK (306 ms)
# [ 87/300] Uploading keywords_curated/goodnight/goodnight.1477.wav OK (375 ms)
# [ 88/300] Uploading keywords_curated/goodnight/goodnight.1354.wav OK (628 ms)
# [ 89/300] Uploading keywords_curated/goodnight/goodnight.0070.wav OK (389 ms)
# [ 90/300] Uploading keywords_curated/goodnight/goodnight.0374.wav OK (446 ms)
# [ 91/300] Uploading keywords_curated/goodnight/goodnight.0377.wav OK (409 ms)
# [ 92/300] Uploading keywords_curated/goodnight/goodnight.0118.wav OK (430 ms)
# [ 93/300] Uploading keywords_curated/goodnight/goodnight.0195.wav OK (378 ms)
# [ 94/300] Uploading keywords_curated/goodnight/goodnight.0525.wav OK (263 ms)
# [ 95/300] Uploading keywords_curated/goodnight/goodnight.0774.wav OK (451 ms)
# [ 96/300] Uploading keywords_curated/goodnight/goodnight.0174.wav OK (511 ms)
# [ 97/300] Uploading keywords_curated/goodnight/goodnight.0858.wav OK (346 ms)
# [ 98/300] Uploading keywords_curated/goodnight/goodnight.0751.wav OK (283 ms)
# [ 99/300] Uploading keywords_curated/goodnight/goodnight.1101.wav OK (552 ms)
# [100/300] Uploading keywords_curated/goodnight/goodnight.1216.wav OK (319 ms)
# [101/300] Uploading keywords_curated/goodnight/goodnight.0578.wav OK (388 ms)
# [102/300] Uploading keywords_curated/goodnight/goodnight.0640.wav OK (391 ms)
# [103/300] Uploading keywords_curated/goodnight/goodnight.0382.wav OK (537 ms)
# [104/300] Uploading keywords_curated/goodnight/goodnight.1097.wav OK (339 ms)
# [105/300] Uploading keywords_curated/goodnight/goodnight.0014.wav OK (448 ms)
# [106/300] Uploading keywords_curated/goodnight/goodnight.1482.wav OK (409 ms)
# [107/300] Uploading keywords_curated/goodnight/goodnight.0132.wav OK (501 ms)
# [108/300] Uploading keywords_curated/goodnight/goodnight.1337.wav OK (456 ms)
# [109/300] Uploading keywords_curated/goodnight/goodnight.1404.wav OK (466 ms)
# [110/300] Uploading keywords_curated/goodnight/goodnight.0086.wav OK (260 ms)
# [111/300] Uploading keywords_curated/goodnight/goodnight.1458.wav OK (446 ms)
# [112/300] Uploading keywords_curated/goodnight/goodnight.0492.wav OK (440 ms)
# [113/300] Uploading keywords_curated/goodnight/goodnight.0786.wav OK (370 ms)
# [114/300] Uploading keywords_curated/goodnight/goodnight.1090.wav OK (284 ms)
# [115/300] Uploading keywords_curated/goodnight/goodnight.0576.wav OK (335 ms)
# [116/300] Uploading keywords_curated/goodnight/goodnight.0462.wav OK (471 ms)
# [117/300] Uploading keywords_curated/goodnight/goodnight.1273.wav OK (305 ms)
# [118/300] Uploading keywords_curated/goodnight/goodnight.0828.wav OK (397 ms)
# [119/300] Uploading keywords_curated/goodnight/goodnight.1045.wav OK (487 ms)
# [120/300] Uploading keywords_curated/goodnight/goodnight.0592.wav OK (383 ms)
# [121/300] Uploading keywords_curated/goodnight/goodnight.0262.wav OK (422 ms)
# [122/300] Uploading keywords_curated/goodnight/goodnight.0776.wav OK (289 ms)
# [123/300] Uploading keywords_curated/goodnight/goodnight.0753.wav OK (468 ms)
# [124/300] Uploading keywords_curated/goodnight/goodnight.1136.wav OK (425 ms)
# [125/300] Uploading keywords_curated/goodnight/goodnight.0038.wav OK (531 ms)
# [126/300] Uploading keywords_curated/goodnight/goodnight.1334.wav OK (463 ms)
# [127/300] Uploading keywords_curated/goodnight/goodnight.1214.wav OK (288 ms)
# [128/300] Uploading keywords_curated/goodnight/goodnight.0849.wav OK (270 ms)
# [129/300] Uploading keywords_curated/goodnight/goodnight.0067.wav OK (440 ms)
# [130/300] Uploading keywords_curated/goodnight/goodnight.1448.wav OK (338 ms)
# [131/300] Uploading keywords_curated/goodnight/goodnight.0474.wav OK (335 ms)
# [132/300] Uploading keywords_curated/goodnight/goodnight.1474.wav OK (488 ms)
# [133/300] Uploading keywords_curated/goodnight/goodnight.0934.wav OK (382 ms)
# [134/300] Uploading keywords_curated/goodnight/goodnight.0466.wav OK (515 ms)
# [135/300] Uploading keywords_curated/goodnight/goodnight.0501.wav OK (412 ms)
# [136/300] Uploading keywords_curated/goodnight/goodnight.0286.wav OK (518 ms)
# [137/300] Uploading keywords_curated/goodnight/goodnight.0795.wav OK (318 ms)
# [138/300] Uploading keywords_curated/goodnight/goodnight.1249.wav OK (314 ms)
# [139/300] Uploading keywords_curated/goodnight/goodnight.0541.wav OK (423 ms)
# [140/300] Uploading keywords_curated/goodnight/goodnight.0739.wav OK (360 ms)
# [141/300] Uploading keywords_curated/goodnight/goodnight.0376.wav OK (299 ms)
# [142/300] Uploading keywords_curated/goodnight/goodnight.0203.wav OK (288 ms)
# [143/300] Uploading keywords_curated/goodnight/goodnight.0182.wav OK (427 ms)
# [144/300] Uploading keywords_curated/goodnight/goodnight.0681.wav OK (484 ms)
# [145/300] Uploading keywords_curated/goodnight/goodnight.0757.wav OK (300 ms)
# [146/300] Uploading keywords_curated/goodnight/goodnight.0010.wav OK (277 ms)
# [147/300] Uploading keywords_curated/goodnight/goodnight.0621.wav OK (307 ms)
# [148/300] Uploading keywords_curated/goodnight/goodnight.1167.wav OK (348 ms)
# [149/300] Uploading keywords_curated/goodnight/goodnight.0861.wav OK (292 ms)
# [150/300] Uploading keywords_curated/goodnight/goodnight.1095.wav OK (283 ms)
# [151/300] Uploading keywords_curated/goodnight/goodnight.0330.wav OK (428 ms)
# [152/300] Uploading keywords_curated/goodnight/goodnight.1315.wav OK (512 ms)
# [153/300] Uploading keywords_curated/goodnight/goodnight.0506.wav OK (487 ms)
# [154/300] Uploading keywords_curated/goodnight/goodnight.1213.wav OK (391 ms)
# [155/300] Uploading keywords_curated/goodnight/goodnight.1187.wav OK (476 ms)
# [156/300] Uploading keywords_curated/goodnight/goodnight.0837.wav OK (566 ms)
# [157/300] Uploading keywords_curated/goodnight/goodnight.1459.wav OK (530 ms)
# [158/300] Uploading keywords_curated/goodnight/goodnight.1446.wav OK (320 ms)
# [159/300] Uploading keywords_curated/goodnight/goodnight.1416.wav OK (515 ms)
# [160/300] Uploading keywords_curated/goodnight/goodnight.0100.wav OK (389 ms)
# [161/300] Uploading keywords_curated/goodnight/goodnight.1263.wav OK (321 ms)
# [162/300] Uploading keywords_curated/goodnight/goodnight.0642.wav OK (563 ms)
# [163/300] Uploading keywords_curated/goodnight/goodnight.0187.wav OK (299 ms)
# [164/300] Uploading keywords_curated/goodnight/goodnight.0800.wav OK (395 ms)
# [165/300] Uploading keywords_curated/goodnight/goodnight.0672.wav OK (397 ms)
# [166/300] Uploading keywords_curated/goodnight/goodnight.0240.wav OK (241 ms)
# [167/300] Uploading keywords_curated/goodnight/goodnight.0933.wav OK (379 ms)
# [168/300] Uploading keywords_curated/goodnight/goodnight.0186.wav OK (331 ms)
# [169/300] Uploading keywords_curated/goodnight/goodnight.0575.wav OK (460 ms)
# [170/300] Uploading keywords_curated/goodnight/goodnight.0261.wav OK (255 ms)
# [171/300] Uploading keywords_curated/goodnight/goodnight.0141.wav OK (452 ms)
# [172/300] Uploading keywords_curated/goodnight/goodnight.0561.wav OK (383 ms)
# [173/300] Uploading keywords_curated/goodnight/goodnight.0416.wav OK (254 ms)
# [174/300] Uploading keywords_curated/goodnight/goodnight.1195.wav OK (443 ms)
# [175/300] Uploading keywords_curated/goodnight/goodnight.0121.wav OK (511 ms)
# [176/300] Uploading keywords_curated/goodnight/goodnight.0298.wav OK (322 ms)
# [177/300] Uploading keywords_curated/goodnight/goodnight.1133.wav OK (362 ms)
# [178/300] Uploading keywords_curated/goodnight/goodnight.0799.wav OK (306 ms)
# [179/300] Uploading keywords_curated/goodnight/goodnight.1417.wav OK (457 ms)
# [180/300] Uploading keywords_curated/goodnight/goodnight.1322.wav OK (385 ms)
# [181/300] Uploading keywords_curated/goodnight/goodnight.0421.wav OK (484 ms)
# [182/300] Uploading keywords_curated/goodnight/goodnight.0740.wav OK (375 ms)
# [183/300] Uploading keywords_curated/goodnight/goodnight.1225.wav OK (421 ms)
# [184/300] Uploading keywords_curated/goodnight/goodnight.1277.wav OK (515 ms)
# [185/300] Uploading keywords_curated/goodnight/goodnight.1464.wav OK (515 ms)
# [186/300] Uploading keywords_curated/goodnight/goodnight.0830.wav OK (501 ms)
# [187/300] Uploading keywords_curated/goodnight/goodnight.1344.wav OK (269 ms)
# [188/300] Uploading keywords_curated/goodnight/goodnight.0549.wav OK (510 ms)
# [189/300] Uploading keywords_curated/goodnight/goodnight.1259.wav OK (515 ms)
# [190/300] Uploading keywords_curated/goodnight/goodnight.0626.wav OK (345 ms)
# [191/300] Uploading keywords_curated/goodnight/goodnight.1385.wav OK (413 ms)
# ...
# [ 985/1200] Uploading keywords_curated/_noise/_noise.0637.wav OK (408 ms)
# [ 986/1200] Uploading keywords_curated/_noise/_noise.1154.wav OK (322 ms)
# [ 987/1200] Uploading keywords_curated/_noise/_noise.0829.wav OK (291 ms)
# [ 988/1200] Uploading keywords_curated/_noise/_noise.0124.wav OK (354 ms)
# [ 989/1200] Uploading keywords_curated/_noise/_noise.0565.wav OK (242 ms)
# [ 990/1200] Uploading keywords_curated/_noise/_noise.0572.wav OK (436 ms)
# [ 991/1200] Uploading keywords_curated/_noise/_noise.0405.wav OK (288 ms)
# [ 992/1200] Uploading keywords_curated/_noise/_noise.1026.wav OK (375 ms)
# [ 993/1200] Uploading keywords_curated/_noise/_noise.0582.wav OK (413 ms)
# [ 994/1200] Uploading keywords_curated/_noise/_noise.1405.wav OK (339 ms)
# [ 995/1200] Uploading keywords_curated/_noise/_noise.0111.wav OK (354 ms)
# [ 996/1200] Uploading keywords_curated/_noise/_noise.1119.wav OK (345 ms)
# [ 997/1200] Uploading keywords_curated/_noise/_noise.0733.wav OK (334 ms)
# [ 998/1200] Uploading keywords_curated/_noise/_noise.1468.wav OK (261 ms)
# [ 999/1200] Uploading keywords_curated/_noise/_noise.1271.wav OK (350 ms)
# [1000/1200] Uploading keywords_curated/_noise/_noise.0859.wav OK (348 ms)
# [1001/1200] Uploading keywords_curated/_noise/_noise.0068.wav OK (296 ms)
# [1002/1200] Uploading keywords_curated/_noise/_noise.0641.wav OK (313 ms)
# [1003/1200] Uploading keywords_curated/_noise/_noise.1240.wav OK (328 ms)
# [1004/1200] Uploading keywords_curated/_noise/_noise.1118.wav OK (426 ms)
# [1005/1200] Uploading keywords_curated/_noise/_noise.0147.wav OK (420 ms)
# [1006/1200] Uploading keywords_curated/_noise/_noise.1098.wav OK (344 ms)
# [1007/1200] Uploading keywords_curated/_noise/_noise.0291.wav OK (309 ms)
# [1008/1200] Uploading keywords_curated/_noise/_noise.0419.wav OK (509 ms)
# [1009/1200] Uploading keywords_curated/_noise/_noise.0353.wav OK (395 ms)
# [1010/1200] Uploading keywords_curated/_noise/_noise.0693.wav OK (299 ms)
# [1011/1200] Uploading keywords_curated/_noise/_noise.0694.wav OK (312 ms)
# [1012/1200] Uploading keywords_curated/_noise/_noise.1299.wav OK (320 ms)
# [1013/1200] Uploading keywords_curated/_noise/_noise.1278.wav OK (277 ms)
# [1014/1200] Uploading keywords_curated/_noise/_noise.1034.wav OK (427 ms)
# [1015/1200] Uploading keywords_curated/_noise/_noise.0736.wav OK (366 ms)
# [1016/1200] Uploading keywords_curated/_noise/_noise.1105.wav OK (345 ms)
# [1017/1200] Uploading keywords_curated/_noise/_noise.0975.wav OK (314 ms)
# [1018/1200] Uploading keywords_curated/_noise/_noise.0249.wav OK (434 ms)
# [1019/1200] Uploading keywords_curated/_noise/_noise.1430.wav OK (286 ms)
# [1020/1200] Uploading keywords_curated/_noise/_noise.0052.wav OK (278 ms)
# [1021/1200] Uploading keywords_curated/_noise/_noise.0314.wav OK (276 ms)
# [1022/1200] Uploading keywords_curated/_noise/_noise.1001.wav OK (435 ms)
# [1023/1200] Uploading keywords_curated/_noise/_noise.0666.wav OK (462 ms)
# [1024/1200] Uploading keywords_curated/_noise/_noise.0701.wav OK (326 ms)
# [1025/1200] Uploading keywords_curated/_noise/_noise.1032.wav OK (315 ms)
# [1026/1200] Uploading keywords_curated/_noise/_noise.0260.wav OK (331 ms)
# [1027/1200] Uploading keywords_curated/_noise/_noise.0996.wav OK (279 ms)
# [1028/1200] Uploading keywords_curated/_noise/_noise.1495.wav OK (355 ms)
# [1029/1200] Uploading keywords_curated/_noise/_noise.0058.wav OK (319 ms)
# [1030/1200] Uploading keywords_curated/_noise/_noise.0303.wav OK (383 ms)
# [1031/1200] Uploading keywords_curated/_noise/_noise.0981.wav OK (389 ms)
# [1032/1200] Uploading keywords_curated/_noise/_noise.0607.wav OK (238 ms)
# [1033/1200] Uploading keywords_curated/_noise/_noise.0670.wav OK (355 ms)
# [1034/1200] Uploading keywords_curated/_noise/_noise.1049.wav OK (260 ms)
# [1035/1200] Uploading keywords_curated/_noise/_noise.0046.wav OK (294 ms)
# [1036/1200] Uploading keywords_curated/_noise/_noise.0795.wav OK (368 ms)
# [1037/1200] Uploading keywords_curated/_noise/_noise.0650.wav OK (269 ms)
# [1038/1200] Uploading keywords_curated/_noise/_noise.0389.wav OK (283 ms)
# [1039/1200] Uploading keywords_curated/_noise/_noise.1136.wav OK (317 ms)
# [1040/1200] Uploading keywords_curated/_noise/_noise.0847.wav OK (355 ms)
# [1041/1200] Uploading keywords_curated/_noise/_noise.1073.wav OK (425 ms)
# [1042/1200] Uploading keywords_curated/_noise/_noise.1314.wav OK (319 ms)
# [1043/1200] Uploading keywords_curated/_noise/_noise.0116.wav OK (490 ms)
# [1044/1200] Uploading keywords_curated/_noise/_noise.0176.wav OK (375 ms)
# [1045/1200] Uploading keywords_curated/_noise/_noise.1493.wav OK (517 ms)
# [1046/1200] Uploading keywords_curated/_noise/_noise.1115.wav OK (443 ms)
# [1047/1200] Uploading keywords_curated/_noise/_noise.1225.wav OK (406 ms)
# [1048/1200] Uploading keywords_curated/_noise/_noise.0683.wav OK (347 ms)
# [1049/1200] Uploading keywords_curated/_noise/_noise.0118.wav OK (452 ms)
# [1050/1200] Uploading keywords_curated/_noise/_noise.1409.wav OK (422 ms)
# [1051/1200] Uploading keywords_curated/_noise/_noise.0571.wav OK (269 ms)
# [1052/1200] Uploading keywords_curated/_noise/_noise.0987.wav OK (258 ms)
# [1053/1200] Uploading keywords_curated/_noise/_noise.0905.wav OK (481 ms)
# [1054/1200] Uploading keywords_curated/_noise/_noise.0808.wav OK (448 ms)
# [1055/1200] Uploading keywords_curated/_noise/_noise.0913.wav OK (348 ms)
# [1056/1200] Uploading keywords_curated/_noise/_noise.0107.wav OK (299 ms)
# [1057/1200] Uploading keywords_curated/_noise/_noise.0529.wav OK (338 ms)
# [1058/1200] Uploading keywords_curated/_noise/_noise.0692.wav OK (298 ms)
# [1059/1200] Uploading keywords_curated/_noise/_noise.1043.wav OK (388 ms)
# [1060/1200] Uploading keywords_curated/_noise/_noise.0283.wav OK (335 ms)
# [1061/1200] Uploading keywords_curated/_noise/_noise.0854.wav OK (256 ms)
# [1062/1200] Uploading keywords_curated/_noise/_noise.0972.wav OK (291 ms)
# [1063/1200] Uploading keywords_curated/_noise/_noise.0623.wav OK (315 ms)
# [1064/1200] Uploading keywords_curated/_noise/_noise.1277.wav OK (416 ms)
# [1065/1200] Uploading keywords_curated/_noise/_noise.0053.wav OK (313 ms)
# [1066/1200] Uploading keywords_curated/_noise/_noise.0769.wav OK (383 ms)
# [1067/1200] Uploading keywords_curated/_noise/_noise.0916.wav OK (309 ms)
# [1068/1200] Uploading keywords_curated/_noise/_noise.0465.wav OK (406 ms)
# [1069/1200] Uploading keywords_curated/_noise/_noise.0711.wav OK (295 ms)
# [1070/1200] Uploading keywords_curated/_noise/_noise.0396.wav OK (407 ms)
# [1071/1200] Uploading keywords_curated/_noise/_noise.0730.wav OK (456 ms)
# [1072/1200] Uploading keywords_curated/_noise/_noise.1096.wav OK (437 ms)
# [1073/1200] Uploading keywords_curated/_noise/_noise.0528.wav OK (495 ms)
# [1074/1200] Uploading keywords_curated/_noise/_noise.0300.wav OK (331 ms)
# [1075/1200] Uploading keywords_curated/_noise/_noise.1469.wav OK (489 ms)
# [1076/1200] Uploading keywords_curated/_noise/_noise.0235.wav OK (341 ms)
# [1077/1200] Uploading keywords_curated/_noise/_noise.0087.wav OK (418 ms)
# [1078/1200] Uploading keywords_curated/_noise/_noise.1023.wav OK (386 ms)
# [1079/1200] Uploading keywords_curated/_noise/_noise.0311.wav OK (456 ms)
# [1080/1200] Uploading keywords_curated/_noise/_noise.0435.wav OK (331 ms)
# [1081/1200] Uploading keywords_curated/_noise/_noise.1027.wav OK (350 ms)
# [1082/1200] Uploading keywords_curated/_noise/_noise.0584.wav OK (329 ms)
# [1083/1200] Uploading keywords_curated/_noise/_noise.0551.wav OK (259 ms)
# [1084/1200] Uploading keywords_curated/_noise/_noise.0771.wav OK (270 ms)
# [1085/1200] Uploading keywords_curated/_noise/_noise.0893.wav OK (292 ms)
# [1086/1200] Uploading keywords_curated/_noise/_noise.1082.wav OK (412 ms)
# [1087/1200] Uploading keywords_curated/_noise/_noise.0912.wav OK (440 ms)
# [1088/1200] Uploading keywords_curated/_noise/_noise.1481.wav OK (313 ms)
# [1089/1200] Uploading keywords_curated/_noise/_noise.0516.wav OK (274 ms)
# [1090/1200] Uploading keywords_curated/_noise/_noise.0392.wav OK (337 ms)
# [1091/1200] Uploading keywords_curated/_noise/_noise.0627.wav OK (363 ms)
# [1092/1200] Uploading keywords_curated/_noise/_noise.0140.wav OK (401 ms)
# [1093/1200] Uploading keywords_curated/_noise/_noise.1155.wav OK (383 ms)
# [1094/1200] Uploading keywords_curated/_noise/_noise.0255.wav OK (312 ms)
# [1095/1200] Uploading keywords_curated/_noise/_noise.0224.wav OK (402 ms)
# [1096/1200] Uploading keywords_curated/_noise/_noise.0512.wav OK (427 ms)
# [1097/1200] Uploading keywords_curated/_noise/_noise.1452.wav OK (331 ms)
# [1098/1200] Uploading keywords_curated/_noise/_noise.0612.wav OK (447 ms)
# [1099/1200] Uploading keywords_curated/_noise/_noise.0791.wav OK (330 ms)
# [1100/1200] Uploading keywords_curated/_noise/_noise.0178.wav OK (341 ms)
# [1101/1200] Uploading keywords_curated/_noise/_noise.1450.wav OK (415 ms)
# [1102/1200] Uploading keywords_curated/_noise/_noise.0441.wav OK (401 ms)
# [1103/1200] Uploading keywords_curated/_noise/_noise.0562.wav OK (318 ms)
# [1104/1200] Uploading keywords_curated/_noise/_noise.1374.wav OK (267 ms)
# [1105/1200] Uploading keywords_curated/_noise/_noise.0779.wav OK (434 ms)
# [1106/1200] Uploading keywords_curated/_noise/_noise.0078.wav OK (244 ms)
# [1107/1200] Uploading keywords_curated/_noise/_noise.0647.wav OK (295 ms)
# [1108/1200] Uploading keywords_curated/_noise/_noise.0960.wav OK (298 ms)
# [1109/1200] Uploading keywords_curated/_noise/_noise.0383.wav OK (300 ms)
# [1110/1200] Uploading keywords_curated/_noise/_noise.0016.wav OK (270 ms)
# [1111/1200] Uploading keywords_curated/_noise/_noise.0588.wav OK (257 ms)
# [1112/1200] Uploading keywords_curated/_noise/_noise.0934.wav OK (304 ms)
# [1113/1200] Uploading keywords_curated/_noise/_noise.1113.wav OK (274 ms)
# [1114/1200] Uploading keywords_curated/_noise/_noise.0017.wav OK (275 ms)
# [1115/1200] Uploading keywords_curated/_noise/_noise.1417.wav OK (585 ms)
# [1116/1200] Uploading keywords_curated/_noise/_noise.0336.wav OK (277 ms)
# [1117/1200] Uploading keywords_curated/_noise/_noise.1435.wav OK (585 ms)
# [1118/1200] Uploading keywords_curated/_noise/_noise.1331.wav OK (617 ms)
# [1119/1200] Uploading keywords_curated/_noise/_noise.1058.wav OK (552 ms)
# [1120/1200] Uploading keywords_curated/_noise/_noise.0479.wav OK (589 ms)
# [1121/1200] Uploading keywords_curated/_noise/_noise.0359.wav OK (591 ms)
# [1122/1200] Uploading keywords_curated/_noise/_noise.1471.wav OK (294 ms)
# [1123/1200] Uploading keywords_curated/_noise/_noise.0818.wav OK (307 ms)
# [1124/1200] Uploading keywords_curated/_noise/_noise.1224.wav OK (558 ms)
# [1125/1200] Uploading keywords_curated/_noise/_noise.0286.wav OK (298 ms)
# [1126/1200] Uploading keywords_curated/_noise/_noise.0634.wav OK (585 ms)
# [1127/1200] Uploading keywords_curated/_noise/_noise.1078.wav OK (440 ms)
# [1128/1200] Uploading keywords_curated/_noise/_noise.0715.wav OK (647 ms)
# [1129/1200] Uploading keywords_curated/_noise/_noise.0072.wav OK (531 ms)
# [1130/1200] Uploading keywords_curated/_noise/_noise.1077.wav OK (688 ms)
# [1131/1200] Uploading keywords_curated/_noise/_noise.1441.wav OK (496 ms)
# [1132/1200] Uploading keywords_curated/_noise/_noise.1052.wav OK (307 ms)
# [1133/1200] Uploading keywords_curated/_noise/_noise.0861.wav OK (621 ms)
# [1134/1200] Uploading keywords_curated/_noise/_noise.0048.wav OK (256 ms)
# [1135/1200] Uploading keywords_curated/_noise/_noise.0644.wav OK (264 ms)
# [1136/1200] Uploading keywords_curated/_noise/_noise.0034.wav OK (408 ms)
# [1137/1200] Uploading keywords_curated/_noise/_noise.1144.wav OK (339 ms)
# [1138/1200] Uploading keywords_curated/_noise/_noise.0464.wav OK (262 ms)
# [1139/1200] Uploading keywords_curated/_noise/_noise.0939.wav OK (311 ms)
# [1140/1200] Uploading keywords_curated/_noise/_noise.0156.wav OK (296 ms)
# [1141/1200] Uploading keywords_curated/_noise/_noise.0218.wav OK (352 ms)
# [1142/1200] Uploading keywords_curated/_noise/_noise.1199.wav OK (263 ms)
# [1143/1200] Uploading keywords_curated/_noise/_noise.0481.wav OK (298 ms)
# [1144/1200] Uploading keywords_curated/_noise/_noise.1342.wav OK (479 ms)
# [1145/1200] Uploading keywords_curated/_noise/_noise.0399.wav OK (260 ms)
# [1146/1200] Uploading keywords_curated/_noise/_noise.1261.wav OK (292 ms)
# [1147/1200] Uploading keywords_curated/_noise/_noise.1309.wav OK (523 ms)
# [1148/1200] Uploading keywords_curated/_noise/_noise.1172.wav OK (452 ms)
# [1149/1200] Uploading keywords_curated/_noise/_noise.0459.wav OK (494 ms)
# [1150/1200] Uploading keywords_curated/_noise/_noise.0420.wav OK (493 ms)
# [1151/1200] Uploading keywords_curated/_noise/_noise.0662.wav OK (574 ms)
# [1152/1200] Uploading keywords_curated/_noise/_noise.0583.wav OK (524 ms)
# [1153/1200] Uploading keywords_curated/_noise/_noise.0342.wav OK (449 ms)
# [1154/1200] Uploading keywords_curated/_noise/_noise.1041.wav OK (595 ms)
# [1155/1200] Uploading keywords_curated/_noise/_noise.0747.wav OK (469 ms)
# [1156/1200] Uploading keywords_curated/_noise/_noise.0298.wav OK (630 ms)
# [1157/1200] Uploading keywords_curated/_noise/_noise.0434.wav OK (259 ms)
# [1158/1200] Uploading keywords_curated/_noise/_noise.0703.wav OK (340 ms)
# [1159/1200] Uploading keywords_curated/_noise/_noise.1454.wav OK (657 ms)
# [1160/1200] Uploading keywords_curated/_noise/_noise.1447.wav OK (425 ms)
# [1161/1200] Uploading keywords_curated/_noise/_noise.1143.wav OK (352 ms)
# [1162/1200] Uploading keywords_curated/_noise/_noise.1396.wav OK (384 ms)
# [1163/1200] Uploading keywords_curated/_noise/_noise.0043.wav OK (316 ms)
# [1164/1200] Uploading keywords_curated/_noise/_noise.0305.wav OK (366 ms)
# [1165/1200] Uploading keywords_curated/_noise/_noise.1485.wav OK (303 ms)
# [1166/1200] Uploading keywords_curated/_noise/_noise.0219.wav OK (364 ms)
# [1167/1200] Uploading keywords_curated/_noise/_noise.0970.wav OK (393 ms)
# [1168/1200] Uploading keywords_curated/_noise/_noise.0267.wav OK (272 ms)
# [1169/1200] Uploading keywords_curated/_noise/_noise.1246.wav OK (279 ms)
# [1170/1200] Uploading keywords_curated/_noise/_noise.0153.wav OK (395 ms)
# [1171/1200] Uploading keywords_curated/_noise/_noise.0648.wav OK (268 ms)
# [1172/1200] Uploading keywords_curated/_noise/_noise.0631.wav OK (366 ms)
# [1173/1200] Uploading keywords_curated/_noise/_noise.1146.wav OK (388 ms)
# [1174/1200] Uploading keywords_curated/_noise/_noise.0154.wav OK (263 ms)
# [1175/1200] Uploading keywords_curated/_noise/_noise.0763.wav OK (261 ms)
# [1176/1200] Uploading keywords_curated/_noise/_noise.1179.wav OK (469 ms)
# [1177/1200] Uploading keywords_curated/_noise/_noise.0172.wav OK (434 ms)
# [1178/1200] Uploading keywords_curated/_noise/_noise.0104.wav OK (275 ms)
# [1179/1200] Uploading keywords_curated/_noise/_noise.0629.wav OK (489 ms)
# [1180/1200] Uploading keywords_curated/_noise/_noise.0626.wav OK (284 ms)
# [1181/1200] Uploading keywords_curated/_noise/_noise.0525.wav OK (308 ms)
# [1182/1200] Uploading keywords_curated/_noise/_noise.1181.wav OK (354 ms)
# [1183/1200] Uploading keywords_curated/_noise/_noise.1423.wav OK (513 ms)
# [1184/1200] Uploading keywords_curated/_noise/_noise.0071.wav OK (334 ms)
# [1185/1200] Uploading keywords_curated/_noise/_noise.1364.wav OK (488 ms)
# [1186/1200] Uploading keywords_curated/_noise/_noise.0045.wav OK (278 ms)
# [1187/1200] Uploading keywords_curated/_noise/_noise.0372.wav OK (271 ms)
# [1188/1200] Uploading keywords_curated/_noise/_noise.1291.wav OK (379 ms)
# [1189/1200] Uploading keywords_curated/_noise/_noise.0603.wav OK (418 ms)
# [1190/1200] Uploading keywords_curated/_noise/_noise.0590.wav OK (316 ms)
# [1191/1200] Uploading keywords_curated/_noise/_noise.0129.wav OK (274 ms)
# [1192/1200] Uploading keywords_curated/_noise/_noise.1166.wav OK (379 ms)
# [1193/1200] Uploading keywords_curated/_noise/_noise.0649.wav OK (437 ms)
# [1194/1200] Uploading keywords_curated/_noise/_noise.1478.wav OK (469 ms)
# [1195/1200] Uploading keywords_curated/_noise/_noise.0532.wav OK (374 ms)
# [1196/1200] Uploading keywords_curated/_noise/_noise.1395.wav OK (275 ms)
# [1197/1200] Uploading keywords_curated/_noise/_noise.1196.wav OK (411 ms)
# [1198/1200] Uploading keywords_curated/_noise/_noise.0539.wav OK (523 ms)
# [1199/1200] Uploading keywords_curated/_noise/_noise.0959.wav OK (350 ms)
# [1200/1200] Uploading keywords_curated/_noise/_noise.0073.wav OK (486 ms)
